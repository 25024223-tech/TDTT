# %% [markdown]
# # Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a,b=map(float,input().split())
S=a*b
C=(a+b)*2
print(f"{S} {C}")
# Out:
# 12 14

# %% [markdown]
# # Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
R=float(input())
S=3.14*R**2
C=2*3.14*R
print(f"{S} {C}")
# Out:
# 50.24 25.12

# %% [markdown]
# # Bài 3 : Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra màn hình.

# %%
a,b,c=map(int,input().split())
if a==0 or b==0 or c==0:
    print("Khong la ba canh cua mot tam giac")
else:
    print("La ba canh cua mot tam giac")
    if a+b>c and a+c>b and b+c>a:
        print("La tam giac")
    else:
        print("Khong la tam giac")
v=a+b+c
p=v/2
s=(p*(p-a)*(p-b)*(p-c))**(1/2)
if a==b==c:
        print("tam giac deu",f"{v} {s}")
elif a==b or a==c or b==c:
        print("Tam giac can",f"{v} {s}") 
elif (a**2+b**2==c**2) or (b**2+c**2==a**2) or (a**2+c**2==b**2):
        print("Tam giac vuong ",f"{v} {s}")
else: 
        print("Tam giac thuong " ,f"{v} {s}")
# Out:
# La ba canh cua mot tam giac
# La tam giac
# Tam giac vuong  12 6.0

# %% [markdown]
# # Bài 4: Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a,b=map(float,input().split())
if a!=0:
    if b!=0:
        print(f'x={-b/a}')
    else: 
        print("x=0")
else:
    if b!=0:
        print("vo nghiem")    
    else:
        print("vo so nghiem")
# Out:
# vo so nghiem

# %% [markdown]
# # Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0

# %%
a,b,c=map(float,input().split())
if a!=0:
    denta=b**2-4*a*c
    print(f"denta")
    if denta>0:
        print(f"x1={-b/a},x2={c/a}")
    elif denta==0:
        print(f"x1=x2={-b/a}")
    else:
        print("vo nghiem")
else:
    if b!=0 and c!=0:
        print("co nghiem ,f {-c/b}") 
    elif b!=0 and c==0:
        print("x=0")     
    else:
        print("vo so nghiem")
# Out:
# vo so nghiem

# %% [markdown]
# # Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím)

# %%
a,b,c,d=map(int,input().split())
print(max(a,b,c,d))
# Out:
# 9

# %% [markdown]
# # Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a,b,c,d,=map(int,input().split())
print(min(a,b,c,d))
# Out:
# 2

# %% [markdown]
# # Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây.

# %%
x=float(input())
so_phut=x/60
so_gio=x/360
so_giay=x
print(f"{so_phut:.2f} {so_gio:.2f} {so_giay:.2f}")
# Out:
# 8150925.92 1358487.65 489055555.00

# %% [markdown]
# # Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
R=int(input())
a,b=map(int,input().split())
I=(a,b)
x1,y1=map(int,input().split())
A=(x1,y1)
if (x1-a)**2+(y1-b)**2-R**2==0:
    print("A thuoc duong tron")
else:
    print("A khong thuoc duong tron")
# Out:
# A khong thuoc duong tron

# %% [markdown]
# # Bài 11: Tính x**y
#  (Với x, y là số thực)

# %%
x,y=map(float,input().split())
tinh = x**y
print(f"{tinh}")
# Out:
# 729.0
